# %% [markdown]
# ### create_audit_table

# %%
# %sql
CREATE TABLE IF NOT EXISTS cicd_dev.bronze.ingestion_audit
(
table_name STRING,
load_time TIMESTAMP,
record_count BIGINT,
status STRING
)
USING DELTA

# %%
# %sql
SHOW TABLES IN cicd_dev.bronze;
