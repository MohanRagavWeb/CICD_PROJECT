# %%
gold_metadata = [

("customer_analytics","gold_customer_analytics"),
("product_analytics","gold_product_analytics"),
("sales_analytics","gold_sales_analytics"),
("inventory_analytics","gold_inventory_analytics")

]

df = spark.createDataFrame(
    gold_metadata,
    ["model_name","gold_table"]
)

df.write.mode("overwrite").saveAsTable(
    "cicd_dev.gold.gold_metadata"
)

display(df)

# %%
# %sql
SELECT *
FROM cicd_dev.gold.gold_metadata;
