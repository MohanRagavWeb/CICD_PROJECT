# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS cicd_dev.gold.gold_audit
(
    table_name STRING,
    load_time TIMESTAMP,
    record_count BIGINT,
    status STRING
)
""")

# %%
# %sql
SHOW TABLES IN cicd_dev.gold;
