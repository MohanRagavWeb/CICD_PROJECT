# %%
silver_metadata = [

("customers_raw","customers"),
("products_raw","products"),
("stores_raw","stores"),
("employees_raw","employees"),
("suppliers_raw","suppliers"),
("sales_raw","sales"),
("returns_raw","returns"),
("payments_raw","payments"),
("inventory_raw","inventory"),
("shipments_raw","shipments")

]

df = spark.createDataFrame(
    silver_metadata,
    ["bronze_table","silver_table"]
)

df.write.mode("overwrite").saveAsTable(
    "cicd_dev.silver.silver_metadata"
)

display(df)

# %%
# %sql
SELECT * FROM cicd_dev.silver.silver_metadata;
